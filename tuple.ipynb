# %%
# Tuple – Question 8 (Medium):
# Write a Python program to unpack the following tuple into individual variables:

t = (10, 20, 30)
a,b,c =t
# print(a,b,c)

# Tuple – Question 9 (Medium):
# Write a Python program to slice the following tuple to get only the middle elements:

t = (10, 20, 30, 40, 50)
print(t[1:4])

# Tuple – Question 10 (Medium → Hard):
# Write a Python program to swap the first and last elements of a tuple.
# Example:
# Output → (5, 2, 3, 4, 1)
Input1 = (1, 2, 3, 4, 5)
# Output → (5, 2, 3, 4, 1)
Input =list(Input1)
Input[0],Input[-1] = Input[-1],Input[0]
print(Input)
# Out:
# (20, 30, 40)
# [5, 2, 3, 4, 1]
