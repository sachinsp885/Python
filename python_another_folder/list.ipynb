# %%
| **Method / Operation**          | **Description**                                       | **Example**            | **Output**      |
| ------------------------------- | ----------------------------------------------------- | ---------------------- | --------------- |
| `append(x)`                     | Add `x` at end                                        | `[1,2,3].append(4)`    | `[1,2,3,4]`     |
| `extend(iterable)`              | Add elements from iterable                            | `[1,2].extend([3,4])`  | `[1,2,3,4]`     |
| `insert(i, x)`                  | Insert `x` at index `i`                               | `[1,2,3].insert(1,10)` | `[1,10,2,3]`    |
| `remove(x)`                     | Remove first occurrence of `x`                        | `[1,2,2,3].remove(2)`  | `[1,2,3]`       |
| `pop([i])`                      | Remove and return element at index `i` (default last) | `[1,2,3].pop()`        | `3 → [1,2]`     |
| `clear()`                       | Remove all elements                                   | `[1,2,3].clear()`      | `[]`            |
| `index(x[, start[, end]])`      | Return index of first occurrence                      | `[1,2,3].index(2)`     | `1`             |
| `count(x)`                      | Count occurrences of `x`                              | `[1,2,2,3].count(2)`   | `2`             |
| `sort(key=None, reverse=False)` | Sort list in place                                    | `[3,1,2].sort()`       | `[1,2,3]`       |
| `reverse()`                     | Reverse list in place                                 | `[1,2,3].reverse()`    | `[3,2,1]`       |
| `copy()`                        | Return shallow copy                                   | `b = a.copy()`         | `[1,2]`         |
| `*`                             | Repeat list                                           | `[1,2]*3`              | `[1,2,1,2,1,2]` |
| `in`                            | Check if element exists                               | `3 in [1,2,3]`         | `True`          |
| `not in`                        | Check if element does not exist                       | `4 not in [1,2,3]`     | `True`          |
| `len(list)`                     | Number of elements                                    | `len([1,2,3])`         | `3`             |
| `sum(list)`                     | Sum numeric elements                                  | `sum([1,2,3])`         | `6`             |
| `min(list)`                     | Minimum element                                       | `min([1,2,3])`         | `1`             |
| `max(list)`                     | Maximum element                                       | `max([1,2,3])`         | `3`             |
| `all(list)`                     | True if all elements truthy                           | `all([1,2,3])`         | `True`          |
| `any(list)`                     | True if any element truthy                            | `any([0,0,1])`         | `True`          |
| `list(iterable)`                | Convert iterable to list                              | `list((1,2,3))`        | `[1,2,3]`       |
| slicing `[start:stop:step]`     | Access subset or reverse                              | `[1,2,3,4][::-1]`      | `[4,3,2,1]`     |
| `del list[i]`                   | Delete element at index or slice                      | `del a[1]`             | `[1,3]`         |
| `*list` (unpacking)             | Expand list in expressions                            | `[*[1,2,3],4]`         | `[1,2,3,4]`     |

# %%
# Question 1 (Simple):
# Write a Python program to print all elements of a list using a for loop.

def print_list_value(l):
    for i in l:
        print(i)
l=[1,2,3,4,5,6]
# print_list_value(l)


# Question 2 (Simple):
# Write a Python program to find the sum of all numbers in a list without using the built-in sum() function.
def sum_list_value(l,count):
    for i in l:
        count=count+i
    return count
l=[1,2,3,4,5,6]
count=0
# print(sum_list_value(l,count))

# Question 3 (Simple → Medium):
# Write a Python program to find the largest number in a list without using the built-in max() function.
def find_large(l):
    l.sort()
    return l[-1]
l=[1,3,4,2,6,9,7]
# print(find_large(l))

# Question 4 (Medium):
# Write a Python program to reverse a list without using reverse() or slicing ([::-1]).
def rev(l, t):
    for i in range(1, len(l)+1):
        t.append(l[-i])
    return t

l = [1, 3, 4, 2, 6, 9, 7]
t = []
# print(rev(l, t))

# Question 5 (Medium):
# Write a Python program to remove duplicates from a list without using set().
# Example:
# Input → [1, 2, 2, 3, 4, 4, 5]
# Output → [1, 2, 3, 4, 5]
Input = [1, 2, 2, 3, 4, 4, 5]
# Output → [1, 2, 3, 4, 5]
output=[]
[output.append(i) for i in Input if i not in output]
# print(output)


# Question 6 (Medium):
# Write a Python program to count how many times each element appears in a list
# without using collections.Counter.
# Example:
# Input → [1, 2, 2, 3, 3, 3]
# Output → {1: 1, 2: 2, 3: 3}
Input = [1, 2, 2, 3, 3, 3]
output={}
print({i:Input.count(i) for i in Input})


# Question 7 (Medium → Hard):
# Write a Python program to find the second largest number in a list
# without using sort() or max().

# Example:
# Input → [10, 20, 4, 45, 99]
# Output → 45

lst = [10, 20, 4, 45, 99]

# find largest
largest = lst[0]
for i in lst:
    if i > largest:
        largest = i

# find second largest
second = lst[0]
for i in lst:
    if i > second and i != largest:
        second = i

print(second)


# Question 8 (Medium):
# Write a Python program to merge two lists index-wise.
# Example:
# Input →
# ["a", "b", "c"]
# [1, 2, 3]
# Output →
# ["a1", "b2", "c3"]
p = ["a", "b", "c"]
l = [1, 2, 3]
output =[]
for i,j in zip(p,l):
    output.append(f"{i}{j}")
print(output)


# Question 9 (Medium):
# Write a Python program to find all even numbers from a list and store them in a new list.
# Example:
# Input → [1, 2, 3, 4, 5, 6]
# Output → [2, 4, 6]
Input = [1, 2, 3, 4, 5, 6]
# Output → [2, 4, 6]
output = []
for i in Input:
    if i%2==0:
        output.append(i)
# print(output)


# Question 10 (Medium):
# Write a Python program to flatten a nested list (a list inside a list).
# Do NOT use recursion.
# Example:
# Output → [1, 2, 3, 4, 5, 6]
Input = [1, [2, 3,[0,9,12,[23,24]]], 4, [5, 6]]

output = []
stack = Input[::-1]   # reverse so we can pop from end

while stack:
    item = stack.pop()
    if isinstance(item, list):
        stack.extend(item[::-1])   # add elements back in reverse
    else:
        output.append(item)

print(output)
# Out:
# {1: 1, 2: 2, 3: 3}
# 45
# ['a1', 'b2', 'c3']
# [1, 2, 3, 0, 9, 12, 23, 24, 4, 5, 6]
